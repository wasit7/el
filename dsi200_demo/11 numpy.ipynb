# %% [markdown]
# # numpy
# * Allocation and Initialization
# * Access
# * Slicing
# * Aggregation
# * argmax() argmin() and sort()
# * Filter
# * Save and Load
# * Image

# %%
# %%sh
# conda install -c conda-forge numpy scikit-image matplotlib

# %%
import numpy as np

# %% [markdown]
# # Allocation without Initialization

# %%
x = np.empty(shape=5)
x
# Out:
# array([4.66992446e-310, 6.94592882e-310, 0.00000000e+000, 0.00000000e+000,
#        8.88782411e+252])

# %%
x.shape
# Out:
# (5,)

# %%
y = np.empty(shape=(2,3))
y
# Out:
# array([[4.66992437e-310, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000]])

# %%
y.shape
# Out:
# (2, 3)

# %% [markdown]
# # Allocation with Initialization

# %%
x = np.zeros(shape=(2,3))
x
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
x = np.ones(shape=(2,3))
x
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
x= np.arange(5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# # Identity Matrix and Linear Space

# %%
x = np.eye(3)
x
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
x = np.linspace(start=-1,stop=1,num=5)
x
# Out:
# array([-1. , -0.5,  0. ,  0.5,  1. ])

# %% [markdown]
# # numpy array from python list

# %%
x = np.array([5,6,7])
x
# Out:
# array([5, 6, 7])

# %%
a_list = [ [2,3,4], [5,6,7] ]
x = np.array(a_list)
x
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
x.shape
# Out:
# (2, 3)

# %% [markdown]
# # Random

# %%
x = np.random.randint(low=0,high=10,size=7)
x
# Out:
# array([8, 8, 6, 5, 6, 4, 0])

# %%
x = np.random.rand(7) #draw samples 7 number from an uniform distribution range between 0 to 1
x
# Out:
# array([0.71053775, 0.59029289, 0.88307727, 0.98926816, 0.77260805,
#        0.0507519 , 0.14441795])

# %%
x = np.random.randn(7)
x
# Out:
# array([ 0.15925367,  0.5333461 , -0.45600494,  1.48206271, -0.39953618,
#         1.42420287,  0.27594385])

# %% [markdown]
# # Access

# %%
np.random.seed(8)
x = np.random.randint(10, size=7)
x
# Out:
# array([3, 4, 1, 9, 5, 8, 3])

# %%
x[0]
# Out:
# 3

# %%
x[1]
# Out:
# 4

# %%
x[-1]
# Out:
# 3

# %%
x[-2]
# Out:
# 8

# %% [markdown]
# # Slicing

# %%
x
# Out:
# array([3, 4, 1, 9, 5, 8, 3])

# %%
x[1:4]
# Out:
# array([4, 1, 9])

# %%
x[1:-1]
# Out:
# array([4, 1, 9, 5, 8])

# %%
x[:]
# Out:
# array([3, 4, 1, 9, 5, 8, 3])

# %%
x[::1]
# Out:
# array([3, 4, 1, 9, 5, 8, 3])

# %%
x[::2]
# Out:
# array([3, 1, 5, 3])

# %%
x[::-1]
# Out:
# array([3, 8, 5, 9, 1, 4, 3])

# %%
x[::-2]
# Out:
# array([3, 5, 1, 3])

# %%
x[::-4]
# Out:
# array([3, 1])

# %% [markdown]
# # Aggregation

# %%
x= np.arange(1,6)
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(np.sum(x))
print(np.prod(x))
print(np.mean(x))
print(np.std(x))
print(np.var(x))
print(np.min(x))
print(np.max(x))
# Out:
# 15
# 120
# 3.0
# 1.4142135623730951
# 2.0
# 1
# 5

# %% [markdown]
# # argmax() argmin() and sort()

# %%
np.random.seed(8)
x = np.random.randint(10, size=7)
x
# Out:
# array([3, 4, 1, 9, 5, 8, 3])

# %%
np.argmax(x)
# Out:
# 3

# %%
np.argmin(x)
# Out:
# 2

# %%
np.sort(x)
# Out:
# array([1, 3, 3, 4, 5, 8, 9])

# %% [markdown]
# # Filter

# %%
x= np.arange(1,6)
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
x<3
# Out:
# array([ True,  True, False, False, False])

# %%
x>3
# Out:
# array([False, False, False,  True,  True])

# %%
#masking pattern
x[x>3]
# Out:
# array([4, 5])

# %%
y=np.where(x>3,7,0)
y
# Out:
# array([0, 0, 0, 7, 7])

# %% [markdown]
# # Element-wise operation

# %%
x=np.array([1,2,3])
y=np.array([4,5,6])

# %%
x+y
# Out:
# array([5, 7, 9])

# %%
x-y
# Out:
# array([-3, -3, -3])

# %%
x*y
# Out:
# array([ 4, 10, 18])

# %%
y/x
# Out:
# array([4. , 2.5, 2. ])

# %%
y//x
# Out:
# array([4, 2, 2])

# %% [markdown]
# # Matrix Operation

# %%
x=np.array([1,2,3])
y=np.array([4,5,6])

# %%
# - If both `a` and `b` are 1-D arrays, it is inner product of vectors
#   (without complex conjugation).

# - If both `a` and `b` are 2-D arrays, it is matrix multiplication,
#   but using :func:`matmul` or ``a @ b`` is preferred.

np.dot(x,y)
# Out:
# 32

# %%
x@y
# Out:
# 32

# %%
x=np.eye(2)
y=np.array([[1,2,3],[4,5,6]])
np.dot(x,y)
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
y.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# # Save and Load

# %%
with open('test.npy', 'wb') as f:
    np.save(f, np.array([1, 2]))
    np.save(f, np.array([1, 3]))
with open('test.npy', 'rb') as f:
    a = np.load(f)
    b = np.load(f)
print(a, b)
# Out:
# [1 2] [1 3]

# %% [markdown]
# # Image

# %%
from skimage import io
img = io.imread('lighthouse.png')

# %%
img.shape
# Out:
# (284, 625, 4)

# %%
import matplotlib.pyplot as plt
plt.imshow(img);

# %%
plt.imshow(img[:,:,:]);

# %%
plt.imshow(img[0:100,400:600,:]);

# %%
plt.imshow(img[::2,:,:]);

# %%
plt.imshow(img[:,::2,:]);

# %%
plt.imshow(img[:,::-1,:]);

# %%
plt.imshow(img[:,:,0].T)
